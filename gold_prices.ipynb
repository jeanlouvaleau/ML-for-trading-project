# %%
import pandas as pd
import numpy as np

# %%
ind = pd.read_csv("Données projet/data US/spptgpj0srq8hyni.csv")

# %%
ind = ind.set_index("DATE")

# %%
ind.sprtrn.cumsum().plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
spy.pct_change().Close.cumsum().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
ind.sprtrn.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
import yfinance as yf
spy = yf.download("SPY", start="2000-01-01")
spy['Adj Close'].plot()
# Out:
# /var/folders/l4/rqys14ws2955nprxbdsj722r0000gn/T/ipykernel_76771/340798629.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   spy = yf.download("SPY", start="2000-01-01")
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/envs/myenv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
spy.columns = spy.columns.get_level_values(0)

# %%
spy
# Out:
# Price            Close        High         Low        Open     Volume
# Date
# 2000-01-03   91.887794   93.664739   90.900603   93.664739    8164300
# 2000-01-04   88.294411   91.019059   88.225307   90.683414    8089800
# 2000-01-05   88.452324   89.419771   86.714868   88.412836   12177900
# 2000-01-06   87.030792   89.400052   87.030792   88.215422    6227200
# 2000-01-07   92.085197   92.085197   88.491821   88.649772    8066500
# ...                ...         ...         ...         ...        ...
# 2025-10-10  653.020020  673.950012  652.840027  672.130005  159422600
# 2025-10-13  663.039978  665.130005  659.770020  660.650024   79560500
# 2025-10-14  662.229980  665.830017  653.169983  657.169983   88779600
# 2025-10-15  665.169983  670.229980  658.929993  666.820007   81602900
# 2025-10-16  658.940002  668.710022  657.109985  666.820007   83875291
#
# [6487 rows x 5 columns]

# %%
sp = pd.read_csv("Données projet/data US/azoglv7iqhksohag.csv")

# %%
sp
# Out:
#     indexname   tic                     companyname
# 0     S&P 500   MMM                      3M Company
# 1     S&P 500   AOS         A. O. Smith Corporation
# 2     S&P 500   AME                    AMETEK, Inc.
# 3     S&P 500   APA                 APA Corporation
# 4     S&P 500     T                       AT&T Inc.
# ..        ...   ...                             ...
# 498   S&P 500  ZBRA  Zebra Technologies Corporation
# 499   S&P 500   ZBH    Zimmer Biomet Holdings, Inc.
# 500   S&P 500   ZTS                     Zoetis Inc.
# 501   S&P 500  EBAY                       eBay Inc.
# 502   S&P 500  LULU        lululemon athletica inc.
#
# [503 rows x 3 columns]

# %%
df = pd.read_csv("Données projet/data US/XAU_USD Historical Data.csv") 
df2 = pd.read_csv("Données projet/data US/XAU_USD Historical Data-2.csv")

# %%
df.Date = pd.to_datetime(df.Date)

# %%
df = df.set_index("Date")

# %%
df
# Out:
#                Price      Open      High       Low  Vol. Change %
# Date
# 2019-03-15  1,301.38  1,295.74  1,306.58  1,293.66   NaN    0.39%
# 2019-03-14  1,296.28  1,309.61  1,310.46  1,292.75   NaN   -0.99%
# 2019-03-13  1,309.28  1,302.01  1,311.33  1,300.56   NaN    0.56%
# 2019-03-12  1,302.01  1,293.71  1,302.19  1,292.06   NaN    0.60%
# 2019-03-11  1,294.25  1,298.70  1,299.27  1,290.15   NaN   -0.32%
# ...              ...       ...       ...       ...   ...      ...
# 2000-01-07    281.75    281.15    281.75    281.75   NaN    0.18%
# 2000-01-06    281.23    280.12    281.23    281.23   NaN    0.08%
# 2000-01-05    281.00    281.50    281.00    281.00   NaN   -0.51%
# 2000-01-04    282.45    288.75    282.45    282.45   NaN   -2.27%
# 2000-01-03    289.00    288.50    289.00    289.00   NaN    0.26%
#
# [5000 rows x 6 columns]

# %%
df.astype(np.float64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df.astype(np.float64)
#
# File /opt/miniconda3/envs/myenv/lib/python3.11/site-packages/pandas/core/generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File /opt/miniconda3/envs/myenv/lib/python3.11/site-packages/pandas/core/internals/managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# ...
